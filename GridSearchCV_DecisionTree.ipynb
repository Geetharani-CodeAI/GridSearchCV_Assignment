# %%
import numpy as np
import matplotlib.pyplot
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent = dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid =  {'criterion':['squared_error','absolute_error','friedman_mse','poisson'],
              'max_features':['none','sqrt','log2'],'splitter':['best','random']}
grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True,verbose = 3, n_jobs = -1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\Hxtreme\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 40 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 40 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Hxtreme\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hxtreme\anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Hxtreme\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Hxtreme\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'none' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Hxtreme\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1102: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.66646189 0.68171378 0.68273206 0.63633038
#         nan        nan 0.6798698  0.6094265  0.61471671 0.62365319
#         nan        nan 0.6267172  0.5991958  0.70093938 0.64843392
#         nan        nan 0.69679796 0.63688424 0.65826301 0.64978031]
#   warnings.warn(
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['none', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
print(grid.best_params_)
re = grid.cv_results_
print(re)
# Out:
# {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'best'}
# {'mean_fit_time': array([0.00700107, 0.00319986, 0.02359757, 0.01599874, 0.01759801,
#        0.01539931, 0.00380111, 0.0052022 , 0.05199609, 0.0479959 ,
#        0.05439649, 0.04259634, 0.00340056, 0.00319972, 0.01839795,
#        0.01399794, 0.01719804, 0.0179996 , 0.00460052, 0.01799788,
#        0.03659678, 0.01999807, 0.02419767, 0.02099762]), 'std_fit_time': array([0.00751071, 0.00040064, 0.0089337 , 0.00303203, 0.00205939,
#        0.00257498, 0.00116683, 0.0034265 , 0.00340679, 0.00853225,
#        0.00557067, 0.00300575, 0.0004893 , 0.00040119, 0.00382558,
#        0.00109524, 0.00240076, 0.00399826, 0.00280006, 0.02850213,
#        0.01828212, 0.00141438, 0.00255917, 0.00141543]), 'mean_score_time': array([0.        , 0.        , 0.02119999, 0.01239862, 0.01380105,
#        0.00939865, 0.        , 0.        , 0.0093997 , 0.00880084,
#        0.01179991, 0.00819917, 0.        , 0.        , 0.0137991 ,
#        0.01020045, 0.01199999, 0.01359901, 0.        , 0.        ,
#        0.01839933, 0.00840073, 0.00940027, 0.00780678]), 'std_score_time': array([0.        , 0.        , 0.01151393, 0.00595182, 0.00649373,
#        0.00135653, 0.        , 0.        , 0.00233348, 0.00116587,
#        0.00716568, 0.00074949, 0.        , 0.        , 0.01110412,
#        0.00193893, 0.00268387, 0.00776072, 0.        , 0.        ,
#        0.01688211, 0.00048956, 0.0013557 , 0.00192983]), 'param_criterion': masked_array(data=['squared_error', 'squared_error', 'squared_error',
#                    'squared_error', 'squared_error', 'squared_error',
#                    'absolute_error', 'absolute_error', 'absolute_error',
#                    'absolute_error', 'absolute_error', 'absolute_error',
#                    'friedman_mse', 'friedman_mse', 'friedman_mse',
#                    'friedman_mse', 'friedman_mse', 'friedman_mse',
#                    'poisson', 'poisson', 'poisson', 'poisson', 'poisson',
#                    'poisson'],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_features': masked_array(data=['none', 'none', 'sqrt', 'sqrt', 'log2', 'log2', 'none',
#                    'none', 'sqrt', 'sqrt', 'log2', 'log2', 'none', 'none',
#                    'sqrt', 'sqrt', 'log2', 'log2', 'none', 'none', 'sqrt',
#                    'sqrt', 'log2', 'log2'],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_splitter': masked_array(data=['best', 'random', 'best', 'random', 'best', 'random',
#                    'best', 'random', 'best', 'random', 'best', 'random',
#                    'best', 'random', 'best', 'random', 'best', 'random',
#                    'best', 'random', 'best', 'random', 'best', 'random'],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'criterion': 'squared_error', 'max_features': 'none', 'splitter': 'best'}, {'criterion': 'squared_error', 'max_features': 'none', 'splitter': 'random'}, {'criterion': 'squared_error', 'max_features': 'sqrt', 'splitter': 'best'}, {'criterion': 'squared_error', 'max_features': 'sqrt', 'splitter': 'random'}, {'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'best'}, {'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'random'}, {'criterion': 'absolute_error', 'max_features': 'none', 'splitter': 'best'}, {'criterion': 'absolute_error', 'max_features': 'none', 'splitter': 'random'}, {'criterion': 'absolute_error', 'max_features': 'sqrt', 'splitter': 'best'}, {'criterion': 'absolute_error', 'max_features': 'sqrt', 'splitter': 'random'}, {'criterion': 'absolute_error', 'max_features': 'log2', 'splitter': 'best'}, {'criterion': 'absolute_error', 'max_features': 'log2', 'splitter': 'random'}, {'criterion': 'friedman_mse', 'max_features': 'none', 'splitter': 'best'}, {'criterion': 'friedman_mse', 'max_features': 'none', 'splitter': 'random'}, {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'splitter': 'best'}, {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'splitter': 'random'}, {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'best'}, {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'random'}, {'criterion': 'poisson', 'max_features': 'none', 'splitter': 'best'}, {'criterion': 'poisson', 'max_features': 'none', 'splitter': 'random'}, {'criterion': 'poisson', 'max_features': 'sqrt', 'splitter': 'best'}, {'criterion': 'poisson', 'max_features': 'sqrt', 'splitter': 'random'}, {'criterion': 'poisson', 'max_features': 'log2', 'splitter': 'best'}, {'criterion': 'poisson', 'max_features': 'log2', 'splitter': 'random'}], 'split0_test_score': array([       nan,        nan, 0.69255838, 0.70780852, 0.73347343,
#        0.71477335,        nan,        nan, 0.67989264, 0.63009847,
#        0.69445794, 0.52885447,        nan,        nan, 0.79087262,
#        0.68711141, 0.69014153, 0.69899945,        nan,        nan,
#        0.74280976, 0.67690199, 0.70824623, 0.5890418 ]), 'split1_test_score': array([       nan,        nan, 0.63099165, 0.57605539, 0.5789281 ,
#        0.59026029,        nan,        nan, 0.58357154, 0.51502349,
#        0.46729047, 0.58337971,        nan,        nan, 0.37302686,
#        0.42497629, 0.6487952 , 0.53433391,        nan,        nan,
#        0.63824016, 0.55375527, 0.51100739, 0.52072273]), 'split2_test_score': array([       nan,        nan, 0.71455875, 0.68139211, 0.74000796,
#        0.68291166,        nan,        nan, 0.64080362, 0.59647175,
#        0.72759423, 0.70921217,        nan,        nan, 0.7169005 ,
#        0.68619711, 0.71602206, 0.68994258,        nan,        nan,
#        0.74811798, 0.64360761, 0.59837354, 0.72630744]), 'split3_test_score': array([       nan,        nan, 0.639843  , 0.68344479, 0.67982486,
#        0.59259882,        nan,        nan, 0.74409587, 0.61950713,
#        0.68036015, 0.68603181,        nan,        nan, 0.62143845,
#        0.55695925, 0.7100842 , 0.65523308,        nan,        nan,
#        0.61899838, 0.68356317, 0.71490842, 0.73988448]), 'split4_test_score': array([       nan,        nan, 0.65435767, 0.7598681 , 0.68142597,
#        0.60110779,        nan,        nan, 0.75098532, 0.68603165,
#        0.5038808 , 0.61078778,        nan,        nan, 0.63134758,
#        0.64073492, 0.73965391, 0.66366058,        nan,        nan,
#        0.73582353, 0.62659314, 0.75877948, 0.67294509]), 'mean_test_score': array([       nan,        nan, 0.66646189, 0.68171378, 0.68273206,
#        0.63633038,        nan,        nan, 0.6798698 , 0.6094265 ,
#        0.61471671, 0.62365319,        nan,        nan, 0.6267172 ,
#        0.5991958 , 0.70093938, 0.64843392,        nan,        nan,
#        0.69679796, 0.63688424, 0.65826301, 0.64978031]), 'std_test_score': array([       nan,        nan, 0.03196107, 0.05992634, 0.05768992,
#        0.05215103,        nan,        nan, 0.06321697, 0.05563641,
#        0.10717104, 0.06631093,        nan,        nan, 0.14105894,
#        0.09915669, 0.03048127, 0.05929036,        nan,        nan,
#        0.05613487, 0.04656582, 0.09064387, 0.08349466]), 'rank_test_score': array([17, 17,  6,  4,  3, 11, 17, 17,  5, 15, 14, 13, 17, 17, 12, 16,  1,
#         9, 17, 17,  2, 10,  7,  8])}

# %%
print("The best R_score value Parameters:{}".format(grid.best_params_))
# Out:
# The best R_score value Parameters:{'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'best'}

# %%
table = pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.007001      0.007511         0.000000        0.000000
# 1        0.003200      0.000401         0.000000        0.000000
# 2        0.023598      0.008934         0.021200        0.011514
# 3        0.015999      0.003032         0.012399        0.005952
# 4        0.017598      0.002059         0.013801        0.006494
# 5        0.015399      0.002575         0.009399        0.001357
# 6        0.003801      0.001167         0.000000        0.000000
# 7        0.005202      0.003426         0.000000        0.000000
# 8        0.051996      0.003407         0.009400        0.002333
# 9        0.047996      0.008532         0.008801        0.001166
# 10       0.054396      0.005571         0.011800        0.007166
# 11       0.042596      0.003006         0.008199        0.000749
# 12       0.003401      0.000489         0.000000        0.000000
# 13       0.003200      0.000401         0.000000        0.000000
# 14       0.018398      0.003826         0.013799        0.011104
# 15       0.013998      0.001095         0.010200        0.001939
# 16       0.017198      0.002401         0.012000        0.002684
# 17       0.018000      0.003998         0.013599        0.007761
# 18       0.004601      0.002800         0.000000        0.000000
# 19       0.017998      0.028502         0.000000        0.000000
# 20       0.036597      0.018282         0.018399        0.016882
# 21       0.019998      0.001414         0.008401        0.000490
# 22       0.024198      0.002559         0.009400        0.001356
# 23       0.020998      0.001415         0.007807        0.001930
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               none           best
# 1    squared_error               none         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6   absolute_error               none           best
# 7   absolute_error               none         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12    friedman_mse               none           best
# 13    friedman_mse               none         random
# 14    friedman_mse               sqrt           best
# 15    friedman_mse               sqrt         random
# 16    friedman_mse               log2           best
# 17    friedman_mse               log2         random
# 18         poisson               none           best
# 19         poisson               none         random
# 20         poisson               sqrt           best
# 21         poisson               sqrt         random
# 22         poisson               log2           best
# 23         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...                NaN
# 1   {'criterion': 'squared_error', 'max_features':...                NaN
# 2   {'criterion': 'squared_error', 'max_features':...           0.692558
# 3   {'criterion': 'squared_error', 'max_features':...           0.707809
# 4   {'criterion': 'squared_error', 'max_features':...           0.733473
# 5   {'criterion': 'squared_error', 'max_features':...           0.714773
# 6   {'criterion': 'absolute_error', 'max_features'...                NaN
# 7   {'criterion': 'absolute_error', 'max_features'...                NaN
# 8   {'criterion': 'absolute_error', 'max_features'...           0.679893
# 9   {'criterion': 'absolute_error', 'max_features'...           0.630098
# 10  {'criterion': 'absolute_error', 'max_features'...           0.694458
# 11  {'criterion': 'absolute_error', 'max_features'...           0.528854
# 12  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 13  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.790873
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.687111
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.690142
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.698999
# 18  {'criterion': 'poisson', 'max_features': 'none...                NaN
# 19  {'criterion': 'poisson', 'max_features': 'none...                NaN
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.742810
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.676902
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.708246
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.589042
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.630992           0.714559           0.639843
# 3            0.576055           0.681392           0.683445
# 4            0.578928           0.740008           0.679825
# 5            0.590260           0.682912           0.592599
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.583572           0.640804           0.744096
# 9            0.515023           0.596472           0.619507
# 10           0.467290           0.727594           0.680360
# 11           0.583380           0.709212           0.686032
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.373027           0.716901           0.621438
# 15           0.424976           0.686197           0.556959
# 16           0.648795           0.716022           0.710084
# 17           0.534334           0.689943           0.655233
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20           0.638240           0.748118           0.618998
# 21           0.553755           0.643608           0.683563
# 22           0.511007           0.598374           0.714908
# 23           0.520723           0.726307           0.739884
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               17
# 1                 NaN              NaN             NaN               17
# 2            0.654358         0.666462        0.031961                6
# 3            0.759868         0.681714        0.059926                4
# 4            0.681426         0.682732        0.057690                3
# 5            0.601108         0.636330        0.052151               11
# 6                 NaN              NaN             NaN               17
# 7                 NaN              NaN             NaN               17
# 8            0.750985         0.679870        0.063217                5
# 9            0.686032         0.609426        0.055636               15
# 10           0.503881         0.614717        0.107171               14
# 11           0.610788         0.623653        0.066311               13
# 12                NaN              NaN             NaN               17
# 13                NaN              NaN             NaN               17
# 14           0.631348         0.626717        0.141059               12
# 15           0.640735         0.599196        0.099157               16
# 16           0.739654         0.700939        0.030481                1
# 17           0.663661         0.648434        0.059290                9
# 18                NaN              NaN             NaN               17
# 19                NaN              NaN             NaN               17
# 20           0.735824         0.696798        0.056135                2
# 21           0.626593         0.636884        0.046566               10
# 22           0.758779         0.658263        0.090644                7
# 23           0.672945         0.649780        0.083495                8

# %%
age = float(input("Age:"))
bmi = float(input("BMI:"))
children = float(input("Children:"))
sex_male = int(input("sex_male 0 or 1:"))
smoker_yes = int(input("smoker_yes 0 or 1"))
Future_Prediction = grid.predict([[age,bmi,children,sex_male,smoker_yes]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Age: 45
# BMI: 23
# Children: 2
# sex_male 0 or 1: 1
# smoker_yes 0 or 1 1
# Future_Prediction=[21098.55405]
# C:\Users\Hxtreme\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
